# %% [markdown]
# # 2024 날씨 빅데이터 콘테스트
#
# ## 전력 분야 - 기상에 따른 공동주택 전력수요 예측 개선

# %%
import pandas as pd
import os 

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/electric_train_cp949.csv', encoding='cp949', index_col=0)
df['electric_train.tm'] = pd.to_datetime(df['electric_train.tm'])

print(df.shape)
# Out:
# (7593355, 16)

# %%
elec_cols = ['electric_train.'+ a for a in ['tm', 'hh24', 'weekday', 'week_name', 'sum_qctr', 'n', 'sum_load', 'n_mean_load', 'elec']]
df_elec = df[elec_cols]
df_elec.head()
# Out:
#     electric_train.tm  electric_train.hh24  electric_train.weekday  \
# 1 2021-01-01 01:00:00                    1                       4
# 2 2021-01-01 02:00:00                    2                       4
# 3 2021-01-01 03:00:00                    3                       4
# 4 2021-01-01 04:00:00                    4                       4
# 5 2021-01-01 05:00:00                    5                       4
#
#    electric_train.week_name  electric_train.sum_qctr  electric_train.n  \
# 1                         0                     6950                11
# 2                         0                     6950                11
# 3                         0                     6950                11
# 4                         0                     6950                11
# 5                         0                     6950                11
#
#    electric_train.sum_load  electric_train.n_mean_load  electric_train.elec
# 1                   751.32                   68.606449                99.56
# 2                   692.60                   68.606449                91.78
# 3                   597.48                   68.606449                79.17
# 4                   553.48                   68.606449                73.34
# 5                   526.24                   68.606449                69.73

# %%
weat_cols = ['electric_train.'+ a for a in ['num', 'stn', 'nph_ta', 'nph_hm', 'nph_ws_10m', 'nph_rn_60m', 'nph_ta_chi']]
df_weat = df[weat_cols]
df_weat.head()
# Out:
#    electric_train.num  electric_train.stn  electric_train.nph_ta  \
# 1                4821                 884                    2.2
# 2                4821                 884                    2.3
# 3                4821                 884                    2.2
# 4                4821                 884                    1.7
# 5                4821                 884                    1.7
#
#    electric_train.nph_hm  electric_train.nph_ws_10m  \
# 1                   62.7                        1.8
# 2                   63.1                        2.1
# 3                   62.4                        2.5
# 4                   63.5                        1.7
# 5                   63.0                        1.6
#
#    electric_train.nph_rn_60m  electric_train.nph_ta_chi
# 1                        0.0                       -1.0
# 2                        0.0                       -0.6
# 3                        0.0                       -1.3
# 4                        0.0                       -0.2
# 5                        0.0                       -0.8

# %%
reset_order_cols = elec_cols + weat_cols

df_new = df[reset_order_cols]

df_new.head()
# Out:
#     electric_train.tm  electric_train.hh24  electric_train.weekday  \
# 1 2021-01-01 01:00:00                    1                       4
# 2 2021-01-01 02:00:00                    2                       4
# 3 2021-01-01 03:00:00                    3                       4
# 4 2021-01-01 04:00:00                    4                       4
# 5 2021-01-01 05:00:00                    5                       4
#
#    electric_train.week_name  electric_train.sum_qctr  electric_train.n  \
# 1                         0                     6950                11
# 2                         0                     6950                11
# 3                         0                     6950                11
# 4                         0                     6950                11
# 5                         0                     6950                11
#
#    electric_train.sum_load  electric_train.n_mean_load  electric_train.elec  \
# 1                   751.32                   68.606449                99.56
# 2                   692.60                   68.606449                91.78
# 3                   597.48                   68.606449                79.17
# 4                   553.48                   68.606449                73.34
# 5                   526.24                   68.606449                69.73
#
#    electric_train.num  electric_train.stn  electric_train.nph_ta  \
# 1                4821                 884                    2.2
# 2                4821                 884                    2.3
# 3                4821                 884                    2.2
# 4                4821                 884                    1.7
# 5                4821                 884                    1.7
#
#    electric_train.nph_hm  electric_train.nph_ws_10m  \
# 1                   62.7                        1.8
# 2                   63.1                        2.1
# 3                   62.4                        2.5
# 4                   63.5                        1.7
# 5                   63.0                        1.6
#
#    electric_train.nph_rn_60m  electric_train.nph_ta_chi
# 1                        0.0                       -1.0
# 2                        0.0                       -0.6
# 3                        0.0                       -1.3
# 4                        0.0                       -0.2
# 5                        0.0                       -0.8

# %%
df_train = df[df['electric_train.tm'] < '2023-01-01']

targets = ['electric_train.sum_qctr', 'electric_train.n', 'electric_train.sum_load', 'electric_train.n_mean_load']

df_val = df[df['electric_train.tm'] >= '2023-01-01'].drop(targets, axis=1)
# df_val는 다른 features에서 계산을 통해 구한 후 채워넣야 할듯? <-- 훈련 데이터에서는 사용하기 때문 (내 생각.....)

# %%
target = 'electric_train.elec'

# %%
targets.append(target)
targets = ['electric_train.tm'] + targets

# %%
df_targets = df_train[targets]

df_targets
# Out:
#           electric_train.tm  electric_train.sum_qctr  electric_train.n  \
# 1       2021-01-01 01:00:00                     6950                11
# 2       2021-01-01 02:00:00                     6950                11
# 3       2021-01-01 03:00:00                     6950                11
# 4       2021-01-01 04:00:00                     6950                11
# 5       2021-01-01 05:00:00                     6950                11
# ...                     ...                      ...               ...
# 7593350 2022-12-31 19:00:00                    34200                23
# 7593351 2022-12-31 20:00:00                    34200                23
# 7593352 2022-12-31 21:00:00                    34200                23
# 7593353 2022-12-31 22:00:00                    34200                23
# 7593354 2022-12-31 23:00:00                    34200                23
#
#          electric_train.sum_load  electric_train.n_mean_load  \
# 1                         751.32                   68.606449
# 2                         692.60                   68.606449
# 3                         597.48                   68.606449
# 4                         553.48                   68.606449
# 5                         526.24                   68.606449
# ...                          ...                         ...
# 7593350                  6851.72                  225.461986
# 7593351                  6779.84                  225.461986
# 7593352                  6802.40                  225.461986
# 7593353                  6706.68                  225.461986
# 7593354                  6355.88                  225.461986
#
#          electric_train.elec
# 1                      99.56
# 2                      91.78
# 3                      79.17
# 4                      73.34
# 5                      69.73
# ...                      ...
# 7593350               132.13
# 7593351               130.74
# 7593352               131.18
# 7593353               129.33
# 7593354               122.57
#
# [7593088 rows x 6 columns]

# %%
df_3am = df_new[df_new['electric_train.tm'].dt.hour == 3]
df_3am.head()
# Out:
#      electric_train.tm  electric_train.hh24  electric_train.weekday  \
# 3  2021-01-01 03:00:00                    3                       4
# 27 2021-01-02 03:00:00                    3                       5
# 51 2021-01-03 03:00:00                    3                       6
# 75 2021-01-04 03:00:00                    3                       0
# 99 2021-01-05 03:00:00                    3                       1
#
#     electric_train.week_name  electric_train.sum_qctr  electric_train.n  \
# 3                          0                     6950                11
# 27                         1                     6950                11
# 51                         1                     6950                11
# 75                         0                     6950                11
# 99                         0                     6950                11
#
#     electric_train.sum_load  electric_train.n_mean_load  electric_train.elec  \
# 3                    597.48                   68.606449                79.17
# 27                   565.64                   68.606449                74.95
# 51                   561.52                   68.606449                74.41
# 75                   559.44                   68.606449                74.13
# 99                   540.80                   68.606449                71.66
#
#     electric_train.num  electric_train.stn  electric_train.nph_ta  \
# 3                 4821                 884                    2.2
# 27                4821                 884                    4.6
# 51                4821                 884                    2.2
# 75                4821                 884                    4.0
# 99                4821                 884                    4.6
#
#     electric_train.nph_hm  electric_train.nph_ws_10m  \
# 3                    62.4                        2.5
# 27                   58.8                        1.5
# 51                   77.6                        1.5
# 75                   61.2                        1.3
# 99                   70.0                        1.6
#
#     electric_train.nph_rn_60m  electric_train.nph_ta_chi
# 3                         0.0                       -1.3
# 27                        0.0                        2.5
# 51                        0.0                        0.0
# 75                        0.0                        2.8
# 99                        0.0                        3.3

# %%
df_1am = df_new[df_new['electric_train.tm'].dt.hour == 0]
a= df_1am[df_1am['electric_train.tm'].between('2020-01-01','2020-01-02')]

a.head()
# Out:
#        electric_train.tm  electric_train.hh24  electric_train.weekday  \
# 8784          2020-01-02                   24                       3
# 35088         2020-01-02                   24                       3
# 61392         2020-01-02                   24                       3
# 105216        2020-01-02                   24                       3
# 114000        2020-01-02                   24                       3
#
#         electric_train.week_name  electric_train.sum_qctr  electric_train.n  \
# 8784                           0                    42250                58
# 35088                          0                    16750                19
# 61392                          0                    14600                11
# 105216                         0                    16100                14
# 114000                         0                     7750                10
#
#         electric_train.sum_load  electric_train.n_mean_load  \
# 8784                    4924.76                   79.776051
# 35088                   2017.52                   97.138634
# 61392                   2837.80                  241.745562
# 105216                  2947.68                  186.873616
# 114000                  1790.80                  156.399551
#
#         electric_train.elec  electric_train.num  electric_train.stn  \
# 8784                 106.44                5565                 184
# 35088                109.31                5566                 184
# 61392                106.72                5567                 330
# 105216               112.67                9735                 165
# 114000               114.50                9736                 774
#
#         electric_train.nph_ta  electric_train.nph_hm  \
# 8784                      6.3                   66.3
# 35088                     6.3                   66.3
# 61392                     4.6                   64.8
# 105216                    5.8                   76.4
# 114000                   -1.9                   84.2
#
#         electric_train.nph_ws_10m  electric_train.nph_rn_60m  \
# 8784                          1.3                        0.0
# 35088                         1.3                        0.0
# 61392                         1.7                        0.0
# 105216                        1.0                        0.0
# 114000                        0.5                        0.0
#
#         electric_train.nph_ta_chi
# 8784                          5.3
# 35088                         5.3
# 61392                         3.0
# 105216                       -0.4
# 114000                       -1.9

# %%
df_val.head()
# Out:
#         electric_train.num electric_train.tm  electric_train.hh24  \
# 35064                 5565        2023-01-01                   24
# 61368                 5566        2023-01-01                   24
# 96432                 8994        2023-01-01                   24
# 140280                9736        2023-01-01                   24
# 166584                9758        2023-01-01                   24
#
#         electric_train.stn  electric_train.nph_ta  electric_train.nph_hm  \
# 35064                  184                    4.8                   66.9
# 61368                  184                    4.8                   66.9
# 96432                  261                   -3.1                   91.7
# 140280                 774                   -1.4                   86.8
# 166584                 168                    3.9                   68.7
#
#         electric_train.nph_ws_10m  electric_train.nph_rn_60m  \
# 35064                         2.9                        0.0
# 61368                         2.9                        0.0
# 96432                         0.2                        0.0
# 140280                        0.9                        0.0
# 166584                        1.6                        0.0
#
#         electric_train.nph_ta_chi  electric_train.weekday  \
# 35064                         2.1                       6
# 61368                         2.1                       6
# 96432                        -3.1                       6
# 140280                       -1.4                       6
# 166584                       -2.2                       6
#
#         electric_train.week_name  electric_train.elec
# 35064                          1                99.64
# 61368                          1               104.26
# 96432                          1               107.96
# 140280                         1               111.51
# 166584                         1               106.43

# %%
df_1am = df_val[df_val['electric_train.tm'].dt.hour == 0]

df_1am.head()
# Out:
#         electric_train.num electric_train.tm  electric_train.hh24  \
# 35064                 5565        2023-01-01                   24
# 61368                 5566        2023-01-01                   24
# 96432                 8994        2023-01-01                   24
# 140280                9736        2023-01-01                   24
# 166584                9758        2023-01-01                   24
#
#         electric_train.stn  electric_train.nph_ta  electric_train.nph_hm  \
# 35064                  184                    4.8                   66.9
# 61368                  184                    4.8                   66.9
# 96432                  261                   -3.1                   91.7
# 140280                 774                   -1.4                   86.8
# 166584                 168                    3.9                   68.7
#
#         electric_train.nph_ws_10m  electric_train.nph_rn_60m  \
# 35064                         2.9                        0.0
# 61368                         2.9                        0.0
# 96432                         0.2                        0.0
# 140280                        0.9                        0.0
# 166584                        1.6                        0.0
#
#         electric_train.nph_ta_chi  electric_train.weekday  \
# 35064                         2.1                       6
# 61368                         2.1                       6
# 96432                        -3.1                       6
# 140280                       -1.4                       6
# 166584                       -2.2                       6
#
#         electric_train.week_name  electric_train.elec
# 35064                          1                99.64
# 61368                          1               104.26
# 96432                          1               107.96
# 140280                         1               111.51
# 166584                         1               106.43

# %%
df_1am = df_val[df_val['electric_train.tm'].dt.hour == 1]

df_1am.head()
# Out:
# Empty DataFrame
# Columns: [electric_train.num, electric_train.tm, electric_train.hh24, electric_train.stn, electric_train.nph_ta, electric_train.nph_hm, electric_train.nph_ws_10m, electric_train.nph_rn_60m, electric_train.nph_ta_chi, electric_train.weekday, electric_train.week_name, electric_train.elec]
# Index: []

# %%
df_1am = df_val[df_val['electric_train.tm'].dt.hour == 2]

df_1am.head()
# Out:
# Empty DataFrame
# Columns: [electric_train.num, electric_train.tm, electric_train.hh24, electric_train.stn, electric_train.nph_ta, electric_train.nph_hm, electric_train.nph_ws_10m, electric_train.nph_rn_60m, electric_train.nph_ta_chi, electric_train.weekday, electric_train.week_name, electric_train.elec]
# Index: []
